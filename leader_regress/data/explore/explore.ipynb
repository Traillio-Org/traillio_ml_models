# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_leetcode = pd.read_json("../leetcode_data.json")
df_leetcode.head()
# Out:
#    totalSolved                                   totalSubmissions  \
# 0          341  [{'difficulty': 'All', 'count': 364, 'submissi...
# 1           46  [{'difficulty': 'All', 'count': 51, 'submissio...
# 2          202  [{'difficulty': 'All', 'count': 214, 'submissi...
# 3          624  [{'difficulty': 'All', 'count': 669, 'submissi...
# 4         1481  [{'difficulty': 'All', 'count': 1522, 'submiss...
#
#    totalQuestions  easySolved  totalEasy  mediumSolved  totalMedium  \
# 0            3451          95        857           212         1795
# 1            3451          18        857            28         1795
# 2            3451          56        857           133         1795
# 3            3451         191        857           334         1795
# 4            3451         400        857           811         1795
#
#    hardSolved  totalHard  ranking  contributionPoint  reputation  \
# 0          34        799   266340               1525           0
# 1           0        799  1911716                565           0
# 2          13        799   550057               1678           0
# 3          99        799    77694               3084           5
# 4         270        799     3997               3673           1
#
#                                   submissionCalendar  \
# 0  {'1710028800': 2, '1711152000': 2, '1711238400...
# 1  {'1724284800': 5, '1725321600': 3, '1725753600...
# 2  {'1715990400': 1, '1716163200': 2, '1716249600...
# 3  {'1708128000': 5, '1708214400': 9, '1708819200...
# 4  {'1707955200': 2, '1708041600': 2, '1708128000...
#
#                                    recentSubmissions  \
# 0  [{'title': 'Assign Elements to Groups with Con...
# 1  [{'title': 'Product of the Last K Numbers', 't...
# 2  [{'title': 'Find Valid Pair of Adjacent Digits...
# 3  [{'title': 'First Completely Painted Row or Co...
# 4  [{'title': 'Count Special Subsequences', 'titl...
#
#                                     matchedUserStats
# 0  {'acSubmissionNum': [{'difficulty': 'All', 'co...
# 1  {'acSubmissionNum': [{'difficulty': 'All', 'co...
# 2  {'acSubmissionNum': [{'difficulty': 'All', 'co...
# 3  {'acSubmissionNum': [{'difficulty': 'All', 'co...
# 4  {'acSubmissionNum': [{'difficulty': 'All', 'co...

# %%
df_codeforces = pd.read_json("../codeforces_data.json")
df_codeforces.head()
# Out:
# C:\Users\nkca1\AppData\Local\Temp\ipykernel_2580\739348592.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_codeforces = pd.read_json("../codeforces_data.json")
# C:\Users\nkca1\AppData\Local\Temp\ipykernel_2580\739348592.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_codeforces = pd.read_json("../codeforces_data.json")
# C:\Users\nkca1\AppData\Local\Temp\ipykernel_2580\739348592.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_codeforces = pd.read_json("../codeforces_data.json")
#    800   900  1000   1100   1200  1300  1400  1500  1600  1700  1800  1900  \
# 0  112  26.0  39.0   34.0   42.0  29.0  16.0   7.0   3.0   4.0   2.0   1.0
# 1   18  13.0  18.0   22.0    7.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   11   NaN   NaN    1.0    2.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   18   1.0   NaN    1.0    NaN   1.0   1.0   NaN   1.0   NaN   NaN   1.0
# 4  131  18.0  37.0  140.0  123.0  63.0  71.0  56.0  80.0   5.0   3.0   2.0
#
#    2000               username  2100  2600
# 0   1.0      tanishqrathore_07   NaN   NaN
# 1   NaN              roysp2003   NaN   NaN
# 2   NaN               kamran-7   NaN   NaN
# 3   NaN               coderncm   NaN   NaN
# 4   1.0  SHUBHAM_SINGH_PATEL__   NaN   NaN
